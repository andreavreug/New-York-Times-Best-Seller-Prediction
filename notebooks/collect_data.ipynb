# %% [markdown]
# *Note: place API keys in .env*

# %% [markdown]
# # Hardcover
# - start date: 2025-01-01
# - 500 books
# - max 20 reviews per book
# - min 3 reviews per book

# %%
from dotenv import load_dotenv, find_dotenv
import os
import requests
import json
import time
import pandas as pd
from pathlib import Path

load_dotenv(find_dotenv())

API_URL = "https://api.hardcover.app/v1/graphql"
START_DATE = "2025-01-01T00:00:00Z"

# -----------------------------
# SMALL SCOPE SETTINGS (edit these)
# -----------------------------
TARGET_BOOKS = 500        # stop once we collected this many unique books
BOOKS_PAGE_LIMIT = 15      # books per page (keep small for 30s server timeout)
MAX_BOOKS_PAGES = 200      # safety cap
MAX_REVIEWS_PER_BOOK = 20  # cap reviews per book to keep dataset small
MIN_REVIEWS_PER_BOOK = 3   # keep only books with at least this many reviews
SLEEP = 1.1                # <= 60 requests/min safe

# -----------------------------
# Queries
# -----------------------------
BOOKS_PAGE_QUERY = """
query BooksPage($limit: Int!, $offset: Int!) {
  activities(
    limit: $limit
    offset: $offset
    where: { book: { created_at: { _gte: "2025-01-01" } } }
  ) {
    book {
      id
      title
      created_at
      description
      contributions { author { name } }
    }
  }
}
"""


REVIEWS_QUERY = f"""
query ReviewsForBook($book_id: Int!) {{
  user_books(
    where: {{
      book_id: {{ _eq: $book_id }}
      has_review: {{ _eq: true }}
    }}
    order_by: {{ created_at: asc }}
    limit: {MAX_REVIEWS_PER_BOOK}
  ) {{
    created_at
    review_raw
  }}
}}
"""


# -----------------------------
# Helpers
# -----------------------------

def get_token():
    token = os.getenv("HARDCOVER_API_KEY")
    if not token:
        raise RuntimeError("HARDCOVER_API_KEY not found in environment")
    return token[7:] if token.startswith("Bearer ") else token

def graphql_post(token, query, variables, operation_name, retries=6):
    headers = {"Authorization": f"Bearer {token}", "Content-Type": "application/json"}
    payload = {"query": query, "variables": variables, "operationName": operation_name}

    for attempt in range(retries):
        resp = requests.post(API_URL, headers=headers, json=payload, timeout=60)

        if resp.status_code in (408, 429, 500, 502, 503, 504):
            wait = min(2 ** attempt, 30)
            print(f"Transient HTTP {resp.status_code}. Retrying in {wait}s...")
            time.sleep(wait)
            continue

        if resp.status_code != 200:
            raise RuntimeError(f"HTTP {resp.status_code}: {resp.text}")

        data = resp.json()
        if "errors" in data:
            raise RuntimeError(json.dumps(data["errors"], indent=2))

        return data["data"]

    raise RuntimeError("Too many retries")


def extract_authors(book):
    names = []
    for c in (book.get("contributions") or []):
        a = c.get("author")
        if a and a.get("name"):
            names.append(a["name"].strip())
    seen = set()
    out = []
    for n in names:
        if n.lower() not in seen:
            out.append(n)
            seen.add(n.lower())
    return ", ".join(out) if out else None


# -----------------------------
# Step A: Fetch books (offset pagination)
# -----------------------------

def fetch_books_offset(token):
    books_by_id = {}
    offset = 0
    page = 1

    while len(books_by_id) < TARGET_BOOKS and page <= MAX_BOOKS_PAGES:
        print(f"[Books] Page {page} (offset={offset}, limit={BOOKS_PAGE_LIMIT}) | collected={len(books_by_id)}/{TARGET_BOOKS}")

        data = graphql_post(
            token,
            BOOKS_PAGE_QUERY,
            {"limit": BOOKS_PAGE_LIMIT, "offset": offset},
            "BooksPage",
        )

        activities = data.get("activities") or []
        if not activities:
            print("[Books] No more results.")
            break

        for act in activities:
            book = act.get("book") or {}
            book_id = book.get("id")
            if book_id is None:
                continue
            if book_id not in books_by_id:
                books_by_id[book_id] = {
                    "book_id": book_id,
                    "title": book.get("title"),
                    "book_created_at": book.get("created_at"),
                    "description": book.get("description"),
                    "authors": extract_authors(book),
                }

        offset += BOOKS_PAGE_LIMIT
        page += 1
        time.sleep(SLEEP)

    return pd.DataFrame(list(books_by_id.values()))


# -----------------------------
# Step B: Reviews (capped)
# -----------------------------

def fetch_reviews(token, books_df):
    rows = []
    total = len(books_df)

    for i, book_id in enumerate(books_df["book_id"].tolist(), start=1):
        print(f"[Reviews] {i}/{total} book_id={book_id}")
        data = graphql_post(token, REVIEWS_QUERY, {"book_id": int(book_id)}, "ReviewsForBook")

        for r in (data.get("user_books") or []):
            txt = r.get("review_raw")
            if txt and txt.strip():
                rows.append({
                    "book_id": book_id,
                    "review_created_at": r.get("created_at"),
                    "review_raw": txt,
                })

        time.sleep(SLEEP)

    return pd.DataFrame(rows)

# -----------------------------
# Main
# -----------------------------

def main():
    token = get_token()

    print("\n=== STEP A: BOOKS (small scope) ===")
    books_df = fetch_books_offset(token)
    print("Books fetched:", books_df.shape)

    print("\n=== STEP B: REVIEWS (capped) ===")
    reviews_df = fetch_reviews(token, books_df)
    print("Reviews fetched:", reviews_df.shape)

    # Keep only books with >= MIN_REVIEWS_PER_BOOK
    if not reviews_df.empty:
        counts = reviews_df.groupby("book_id").size()
        keep_ids = counts[counts >= MIN_REVIEWS_PER_BOOK].index
        reviews_df = reviews_df[reviews_df["book_id"].isin(keep_ids)].reset_index(drop=True)
        books_df = books_df[books_df["book_id"].isin(keep_ids)].reset_index(drop=True)

    print("\nAfter min-review filter:")
    print("Books:", books_df.shape, "| Reviews:", reviews_df.shape)

    print("\n=== JOIN ===")
    final_df = reviews_df.merge(books_df, on="book_id", how="left")
    print("Final dataset:", final_df.shape)
    print(final_df.head(5).to_string(index=False))

    out = Path('..') / 'data' / "Hardcover_2025.csv"
    (Path('..') / 'data').mkdir(parents=True, exist_ok=True)
    final_df.to_csv(str(out), index=False, encoding="utf-8")
    print(f"\nSaved: {out}")

if __name__ == "__main__":
    main()
# Out:
# === STEP A: BOOKS (small scope) ===
# [Books] Page 1 (offset=0, limit=15) | collected=0/500
# [Books] Page 2 (offset=15, limit=15) | collected=14/500
# [Books] Page 3 (offset=30, limit=15) | collected=28/500
# [Books] Page 4 (offset=45, limit=15) | collected=41/500
# [Books] Page 5 (offset=60, limit=15) | collected=55/500
# [Books] Page 6 (offset=75, limit=15) | collected=69/500
# [Books] Page 7 (offset=90, limit=15) | collected=83/500
# [Books] Page 8 (offset=105, limit=15) | collected=95/500
# [Books] Page 9 (offset=120, limit=15) | collected=107/500
# [Books] Page 10 (offset=135, limit=15) | collected=121/500
# [Books] Page 11 (offset=150, limit=15) | collected=136/500
# [Books] Page 12 (offset=165, limit=15) | collected=148/500
# [Books] Page 13 (offset=180, limit=15) | collected=162/500
# [Books] Page 14 (offset=195, limit=15) | collected=173/500
# [Books] Page 15 (offset=210, limit=15) | collected=185/500
# [Books] Page 16 (offset=225, limit=15) | collected=200/500
# [Books] Page 17 (offset=240, limit=15) | collected=210/500
# [Books] Page 18 (offset=255, limit=15) | collected=223/500
# [Books] Page 19 (offset=270, limit=15) | collected=236/500
# [Books] Page 20 (offset=285, limit=15) | collected=249/500
# [Books] Page 21 (offset=300, limit=15) | collected=262/500
# [Books] Page 22 (offset=315, limit=15) | collected=274/500
# [Books] Page 23 (offset=330, limit=15) | collected=285/500
# [Books] Page 24 (offset=345, limit=15) | collected=298/500
# [Books] Page 25 (offset=360, limit=15) | collected=309/500
# [Books] Page 26 (offset=375, limit=15) | collected=320/500
# [Books] Page 27 (offset=390, limit=15) | collected=332/500
# [Books] Page 28 (offset=405, limit=15) | collected=345/500
# [Books] Page 29 (offset=420, limit=15) | collected=359/500
# [Books] Page 30 (offset=435, limit=15) | collected=370/500
# [Books] Page 31 (offset=450, limit=15) | collected=381/500
# [Books] Page 32 (offset=465, limit=15) | collected=392/500
# [Books] Page 33 (offset=480, limit=15) | collected=404/500
# [Books] Page 34 (offset=495, limit=15) | collected=414/500
# [Books] Page 35 (offset=510, limit=15) | collected=426/500
# [Books] Page 36 (offset=525, limit=15) | collected=441/500
# [Books] Page 37 (offset=540, limit=15) | collected=454/500
# [Books] Page 38 (offset=555, limit=15) | collected=467/500
# [Books] Page 39 (offset=570, limit=15) | collected=475/500
# [Books] Page 40 (offset=585, limit=15) | collected=487/500
# [Books] Page 41 (offset=600, limit=15) | collected=498/500
# Books fetched: (513, 5)
#
# === STEP B: REVIEWS (capped) ===
# [Reviews] 1/513 book_id=2004227
# [Reviews] 2/513 book_id=2319733
# [Reviews] 3/513 book_id=1995481
# [Reviews] 4/513 book_id=2004257
# [Reviews] 5/513 book_id=2414822
# [Reviews] 6/513 book_id=2007074
# [Reviews] 7/513 book_id=2319734
# [Reviews] 8/513 book_id=1771763
# [Reviews] 9/513 book_id=2319737
# [Reviews] 10/513 book_id=2251889
# [Reviews] 11/513 book_id=2251839
# [Reviews] 12/513 book_id=2319735
# [Reviews] 13/513 book_id=2222424
# [Reviews] 14/513 book_id=2313816
# [Reviews] 15/513 book_id=2319762
# [Reviews] 16/513 book_id=1713534
# [Reviews] 17/513 book_id=1684749
# [Reviews] 18/513 book_id=2414824
# [Reviews] 19/513 book_id=2319740
# [Reviews] 20/513 book_id=1726780
# [Reviews] 21/513 book_id=1768202
# [Reviews] 22/513 book_id=2319306
# [Reviews] 23/513 book_id=1727792
# [Reviews] 24/513 book_id=1832979
# [Reviews] 25/513 book_id=1940583
# [Reviews] 26/513 book_id=2141963
# [Reviews] 27/513 book_id=1980783
# [Reviews] 28/513 book_id=2319763
# [Reviews] 29/513 book_id=1944367
# [Reviews] 30/513 book_id=2319779
# [Reviews] 31/513 book_id=1775930
# [Reviews] 32/513 book_id=2017157
# [Reviews] 33/513 book_id=1765480
# [Reviews] 34/513 book_id=2132282
# [Reviews] 35/513 book_id=2093984
# [Reviews] 36/513 book_id=2415446
# [Reviews] 37/513 book_id=2415447
# [Reviews] 38/513 book_id=2014111
# [Reviews] 39/513 book_id=1842229
# [Reviews] 40/513 book_id=2199944
# [Reviews] 41/513 book_id=2319770
# [Reviews] 42/513 book_id=2415445
# [Reviews] 43/513 book_id=2136173
# [Reviews] 44/513 book_id=2319774
# [Reviews] 45/513 book_id=2019019
# [Reviews] 46/513 book_id=2319775
# [Reviews] 47/513 book_id=2319776
# [Reviews] 48/513 book_id=1953185
# [Reviews] 49/513 book_id=2249230
# [Reviews] 50/513 book_id=2319778
# [Reviews] 51/513 book_id=2313619
# [Reviews] 52/513 book_id=1993298
# [Reviews] 53/513 book_id=2043361
# [Reviews] 54/513 book_id=2097472
# [Reviews] 55/513 book_id=1774864
# [Reviews] 56/513 book_id=1838031
# [Reviews] 57/513 book_id=1688054
# [Reviews] 58/513 book_id=1903310
# [Reviews] 59/513 book_id=1861246
# [Reviews] 60/513 book_id=2414874
# [Reviews] 61/513 book_id=1917708
# [Reviews] 62/513 book_id=2124513
# [Reviews] 63/513 book_id=1939847
# [Reviews] 64/513 book_id=2319791
# [Reviews] 65/513 book_id=1875356
# [Reviews] 66/513 book_id=2319789
# [Reviews] 67/513 book_id=1891675
# [Reviews] 68/513 book_id=1827484
# [Reviews] 69/513 book_id=1820138
# [Reviews] 70/513 book_id=1819200
# [Reviews] 71/513 book_id=2356005
# [Reviews] 72/513 book_id=1662572
# [Reviews] 73/513 book_id=2374850
# [Reviews] 74/513 book_id=1957419
# [Reviews] 75/513 book_id=1758509
# [Reviews] 76/513 book_id=2391247
# [Reviews] 77/513 book_id=1768096
# [Reviews] 78/513 book_id=1819201
# [Reviews] 79/513 book_id=2319795
# [Reviews] 80/513 book_id=1939375
# [Reviews] 81/513 book_id=1989600
# [Reviews] 82/513 book_id=2124255
# [Reviews] 83/513 book_id=2170358
# [Reviews] 84/513 book_id=1719073
# [Reviews] 85/513 book_id=2339634
# [Reviews] 86/513 book_id=2137695
# [Reviews] 87/513 book_id=1959024
# [Reviews] 88/513 book_id=1765415
# [Reviews] 89/513 book_id=1853400
# [Reviews] 90/513 book_id=2297990
# [Reviews] 91/513 book_id=2041573
# [Reviews] 92/513 book_id=1946606
# [Reviews] 93/513 book_id=2311965
# [Reviews] 94/513 book_id=2414882
# [Reviews] 95/513 book_id=2136026
# [Reviews] 96/513 book_id=2180155
# [Reviews] 97/513 book_id=1915687
# [Reviews] 98/513 book_id=1891829
# [Reviews] 99/513 book_id=2060091
# [Reviews] 100/513 book_id=1898835
# [Reviews] 101/513 book_id=1823410
# [Reviews] 102/513 book_id=1905936
# [Reviews] 103/513 book_id=2283992
# [Reviews] 104/513 book_id=1986562
# [Reviews] 105/513 book_id=2296973
# [Reviews] 106/513 book_id=2103421
# [Reviews] 107/513 book_id=1934927
# [Reviews] 108/513 book_id=1946679
# [Reviews] 109/513 book_id=1675890
# [Reviews] 110/513 book_id=1707888
# [Reviews] 111/513 book_id=2126481
# [Reviews] 112/513 book_id=1700874
# [Reviews] 113/513 book_id=2079917
# [Reviews] 114/513 book_id=1859368
# [Reviews] 115/513 book_id=2075078
# [Reviews] 116/513 book_id=2115990
# [Reviews] 117/513 book_id=1859525
# [Reviews] 118/513 book_id=1985890
# [Reviews] 119/513 book_id=2142602
# [Reviews] 120/513 book_id=2340805
# [Reviews] 121/513 book_id=2142604
# [Reviews] 122/513 book_id=1879363
# [Reviews] 123/513 book_id=2124500
# [Reviews] 124/513 book_id=1859832
# [Reviews] 125/513 book_id=2356095
# [Reviews] 126/513 book_id=1771722
# [Reviews] 127/513 book_id=2149453
# [Reviews] 128/513 book_id=1765414
# [Reviews] 129/513 book_id=2142867
# [Reviews] 130/513 book_id=1922707
# [Reviews] 131/513 book_id=1958360
# [Reviews] 132/513 book_id=2321483
# [Reviews] 133/513 book_id=1846950
# [Reviews] 134/513 book_id=1814664
# [Reviews] 135/513 book_id=2415597
# [Reviews] 136/513 book_id=1905947
# [Reviews] 137/513 book_id=2131889
# [Reviews] 138/513 book_id=2322260
# [Reviews] 139/513 book_id=2132572
# [Reviews] 140/513 book_id=1961825
# [Reviews] 141/513 book_id=2042065
# [Reviews] 142/513 book_id=1838380
# [Reviews] 143/513 book_id=1838371
# [Reviews] 144/513 book_id=1983951
# [Reviews] 145/513 book_id=2086444
# [Reviews] 146/513 book_id=1960841
# [Reviews] 147/513 book_id=1838734
# [Reviews] 148/513 book_id=2315874
# [Reviews] 149/513 book_id=2415632
# [Reviews] 150/513 book_id=2415634
# [Reviews] 151/513 book_id=1659340
# [Reviews] 152/513 book_id=1744802
# [Reviews] 153/513 book_id=1951278
# [Reviews] 154/513 book_id=2136172
# [Reviews] 155/513 book_id=2356572
# [Reviews] 156/513 book_id=2356377
# [Reviews] 157/513 book_id=2143515
# [Reviews] 158/513 book_id=2250007
# [Reviews] 159/513 book_id=2312312
# [Reviews] 160/513 book_id=2238134
# [Reviews] 161/513 book_id=1786778
# [Reviews] 162/513 book_id=2322079
# [Reviews] 163/513 book_id=2131941
# [Reviews] 164/513 book_id=1838512
# [Reviews] 165/513 book_id=1953994
# [Reviews] 166/513 book_id=1729702
# [Reviews] 167/513 book_id=2145769
# [Reviews] 168/513 book_id=1922158
# [Reviews] 169/513 book_id=1774653
# [Reviews] 170/513 book_id=2135976
# [Reviews] 171/513 book_id=2274359
# [Reviews] 172/513 book_id=2417529
# [Reviews] 173/513 book_id=1817542
# [Reviews] 174/513 book_id=2028071
# [Reviews] 175/513 book_id=2043090
# [Reviews] 176/513 book_id=2022703
# [Reviews] 177/513 book_id=2003065
# [Reviews] 178/513 book_id=2143833
# [Reviews] 179/513 book_id=1886206
# [Reviews] 180/513 book_id=2049419
# [Reviews] 181/513 book_id=2143831
# [Reviews] 182/513 book_id=2143739
# [Reviews] 183/513 book_id=1771398
# [Reviews] 184/513 book_id=1687801
# [Reviews] 185/513 book_id=1909139
# [Reviews] 186/513 book_id=2037726
# [Reviews] 187/513 book_id=1788666
# [Reviews] 188/513 book_id=1825216
# [Reviews] 189/513 book_id=2020875
# [Reviews] 190/513 book_id=2059464
# [Reviews] 191/513 book_id=2143606
# [Reviews] 192/513 book_id=1659489
# [Reviews] 193/513 book_id=2417037
# [Reviews] 194/513 book_id=2321974
# [Reviews] 195/513 book_id=1890824
# [Reviews] 196/513 book_id=2070090
# [Reviews] 197/513 book_id=2137776
# [Reviews] 198/513 book_id=2087963
# [Reviews] 199/513 book_id=1760882
# [Reviews] 200/513 book_id=1714145
# [Reviews] 201/513 book_id=2015380
# [Reviews] 202/513 book_id=1940646
# [Reviews] 203/513 book_id=1775705
# [Reviews] 204/513 book_id=2117289
# [Reviews] 205/513 book_id=1772962
# [Reviews] 206/513 book_id=2345842
# [Reviews] 207/513 book_id=1837227
# [Reviews] 208/513 book_id=2390451
# [Reviews] 209/513 book_id=2403351
# [Reviews] 210/513 book_id=1839251
# [Reviews] 211/513 book_id=1950990
# [Reviews] 212/513 book_id=2192497
# [Reviews] 213/513 book_id=1666955
# [Reviews] 214/513 book_id=1696328
# [Reviews] 215/513 book_id=2322078
# [Reviews] 216/513 book_id=1891301
# [Reviews] 217/513 book_id=1667498
# [Reviews] 218/513 book_id=1798991
# [Reviews] 219/513 book_id=2110527
# [Reviews] 220/513 book_id=2318453
# [Reviews] 221/513 book_id=2243066
# [Reviews] 222/513 book_id=1728682
# [Reviews] 223/513 book_id=2292363
# [Reviews] 224/513 book_id=2002477
# [Reviews] 225/513 book_id=2142787
# [Reviews] 226/513 book_id=2131602
# [Reviews] 227/513 book_id=2014104
# [Reviews] 228/513 book_id=1858216
# [Reviews] 229/513 book_id=2022739
# [Reviews] 230/513 book_id=2383284
# [Reviews] 231/513 book_id=1970432
# [Reviews] 232/513 book_id=2147064
# [Reviews] 233/513 book_id=2133020
# [Reviews] 234/513 book_id=2073042
# [Reviews] 235/513 book_id=1676690
# [Reviews] 236/513 book_id=1682763
# [Reviews] 237/513 book_id=1666467
# [Reviews] 238/513 book_id=2322237
# [Reviews] 239/513 book_id=2131693
# [Reviews] 240/513 book_id=2004201
# [Reviews] 241/513 book_id=2322187
# [Reviews] 242/513 book_id=2410055
# [Reviews] 243/513 book_id=1762588
# [Reviews] 244/513 book_id=1908128
# [Reviews] 245/513 book_id=2179144
# [Reviews] 246/513 book_id=2007614
# [Reviews] 247/513 book_id=2014854
# [Reviews] 248/513 book_id=1901388
# [Reviews] 249/513 book_id=1801904
# [Reviews] 250/513 book_id=1980442
# [Reviews] 251/513 book_id=2026998
# [Reviews] 252/513 book_id=1817296
# [Reviews] 253/513 book_id=1673433
# [Reviews] 254/513 book_id=2022736
# [Reviews] 255/513 book_id=2200518
# [Reviews] 256/513 book_id=1695308
# [Reviews] 257/513 book_id=2322859
# [Reviews] 258/513 book_id=1938541
# [Reviews] 259/513 book_id=2142531
# [Reviews] 260/513 book_id=2275189
# [Reviews] 261/513 book_id=1799032
# [Reviews] 262/513 book_id=1925307
# [Reviews] 263/513 book_id=1843574
# [Reviews] 264/513 book_id=2324346
# [Reviews] 265/513 book_id=2009299
# [Reviews] 266/513 book_id=2149585
# [Reviews] 267/513 book_id=2149681
# [Reviews] 268/513 book_id=1951804
# [Reviews] 269/513 book_id=1775710
# [Reviews] 270/513 book_id=2150433
# [Reviews] 271/513 book_id=2096775
# [Reviews] 272/513 book_id=2322784
# [Reviews] 273/513 book_id=1749218
# [Reviews] 274/513 book_id=2324347
# [Reviews] 275/513 book_id=2150263
# [Reviews] 276/513 book_id=1890965
# [Reviews] 277/513 book_id=1813220
# [Reviews] 278/513 book_id=1969235
# [Reviews] 279/513 book_id=2150267
# [Reviews] 280/513 book_id=2150268
# [Reviews] 281/513 book_id=1908605
# [Reviews] 282/513 book_id=1772168
# [Reviews] 283/513 book_id=2323725
# [Reviews] 284/513 book_id=1967654
# [Reviews] 285/513 book_id=2150270
# [Reviews] 286/513 book_id=1827208
# [Reviews] 287/513 book_id=2094056
# [Reviews] 288/513 book_id=1916024
# [Reviews] 289/513 book_id=2150686
# [Reviews] 290/513 book_id=1946063
# [Reviews] 291/513 book_id=2142305
# [Reviews] 292/513 book_id=2048100
# [Reviews] 293/513 book_id=2111721
# [Reviews] 294/513 book_id=1725379
# [Reviews] 295/513 book_id=1917265
# [Reviews] 296/513 book_id=1698858
# [Reviews] 297/513 book_id=1808557
# [Reviews] 298/513 book_id=2161879
# [Reviews] 299/513 book_id=1856236
# [Reviews] 300/513 book_id=2324593
# [Reviews] 301/513 book_id=1878193
# [Reviews] 302/513 book_id=1709506
# [Reviews] 303/513 book_id=1716372
# [Reviews] 304/513 book_id=2145764
# [Reviews] 305/513 book_id=2291300
# [Reviews] 306/513 book_id=2153354
# [Reviews] 307/513 book_id=2288586
# [Reviews] 308/513 book_id=1883444
# [Reviews] 309/513 book_id=1859075
# [Reviews] 310/513 book_id=1725609
# [Reviews] 311/513 book_id=2154938
# [Reviews] 312/513 book_id=2032367
# [Reviews] 313/513 book_id=2141604
# [Reviews] 314/513 book_id=2153421
# [Reviews] 315/513 book_id=2155348
# [Reviews] 316/513 book_id=2020140
# [Reviews] 317/513 book_id=1701283
# [Reviews] 318/513 book_id=1670203
# [Reviews] 319/513 book_id=1759755
# [Reviews] 320/513 book_id=2155478
# [Reviews] 321/513 book_id=2133046
# [Reviews] 322/513 book_id=1938161
# [Reviews] 323/513 book_id=2031890
# [Reviews] 324/513 book_id=1930085
# [Reviews] 325/513 book_id=2096770
# [Reviews] 326/513 book_id=1968954
# [Reviews] 327/513 book_id=1908665
# [Reviews] 328/513 book_id=2324913
# [Reviews] 329/513 book_id=1673839
# [Reviews] 330/513 book_id=2117031
# [Reviews] 331/513 book_id=2325885
# [Reviews] 332/513 book_id=2324908
# [Reviews] 333/513 book_id=2325447
# [Reviews] 334/513 book_id=2325445
# [Reviews] 335/513 book_id=1828535
# [Reviews] 336/513 book_id=2137033
# [Reviews] 337/513 book_id=1787539
# [Reviews] 338/513 book_id=2170040
# [Reviews] 339/513 book_id=2378953
# [Reviews] 340/513 book_id=2133758
# [Reviews] 341/513 book_id=2325977
# [Reviews] 342/513 book_id=1765490
# [Reviews] 343/513 book_id=1787541
# [Reviews] 344/513 book_id=1667561
# [Reviews] 345/513 book_id=2156367
# [Reviews] 346/513 book_id=1734513
# [Reviews] 347/513 book_id=1776567
# [Reviews] 348/513 book_id=2119357
# [Reviews] 349/513 book_id=1855727
# [Reviews] 350/513 book_id=2156662
# [Reviews] 351/513 book_id=1940699
# [Reviews] 352/513 book_id=1666680
# [Reviews] 353/513 book_id=2325675
# [Reviews] 354/513 book_id=2325681
# [Reviews] 355/513 book_id=1931960
# [Reviews] 356/513 book_id=2181142
# [Reviews] 357/513 book_id=2295641
# [Reviews] 358/513 book_id=2156947
# [Reviews] 359/513 book_id=2157173
# [Reviews] 360/513 book_id=1839248
# [Reviews] 361/513 book_id=1855017
# [Reviews] 362/513 book_id=2380135
# [Reviews] 363/513 book_id=2157908
# [Reviews] 364/513 book_id=2157911
# [Reviews] 365/513 book_id=2157909
# [Reviews] 366/513 book_id=2326658
# [Reviews] 367/513 book_id=2157910
# [Reviews] 368/513 book_id=1845663
# [Reviews] 369/513 book_id=1908076
# [Reviews] 370/513 book_id=1928162
# [Reviews] 371/513 book_id=2159277
# [Reviews] 372/513 book_id=1905977
# [Reviews] 373/513 book_id=1906891
# [Reviews] 374/513 book_id=2143979
# [Reviews] 375/513 book_id=1891472
# [Reviews] 376/513 book_id=1673922
# [Reviews] 377/513 book_id=2159278
# [Reviews] 378/513 book_id=1838149
# [Reviews] 379/513 book_id=1686947
# [Reviews] 380/513 book_id=2008226
# [Reviews] 381/513 book_id=1726762
# [Reviews] 382/513 book_id=2149509
# [Reviews] 383/513 book_id=2269863
# [Reviews] 384/513 book_id=2189703
# [Reviews] 385/513 book_id=2328461
# [Reviews] 386/513 book_id=2381036
# [Reviews] 387/513 book_id=2323876
# [Reviews] 388/513 book_id=1672564
# [Reviews] 389/513 book_id=1818922
# [Reviews] 390/513 book_id=1859517
# [Reviews] 391/513 book_id=2111005
# [Reviews] 392/513 book_id=1993284
# [Reviews] 393/513 book_id=2164208
# [Reviews] 394/513 book_id=1821310
# [Reviews] 395/513 book_id=2006005
# [Reviews] 396/513 book_id=2164605
# [Reviews] 397/513 book_id=2164165
# [Reviews] 398/513 book_id=2164168
# [Reviews] 399/513 book_id=2100694
# [Reviews] 400/513 book_id=2164166
# [Reviews] 401/513 book_id=2164167
# [Reviews] 402/513 book_id=1785259
# [Reviews] 403/513 book_id=2164209
# [Reviews] 404/513 book_id=2329229
# [Reviews] 405/513 book_id=2027845
# [Reviews] 406/513 book_id=1960471
# [Reviews] 407/513 book_id=2097151
# [Reviews] 408/513 book_id=2100666
# [Reviews] 409/513 book_id=1913643
# [Reviews] 410/513 book_id=2062764
# [Reviews] 411/513 book_id=1670990
# [Reviews] 412/513 book_id=1670992
# [Reviews] 413/513 book_id=1931473
# [Reviews] 414/513 book_id=1824615
# [Reviews] 415/513 book_id=2329252
# [Reviews] 416/513 book_id=2048876
# [Reviews] 417/513 book_id=1927190
# [Reviews] 418/513 book_id=1676196
# [Reviews] 419/513 book_id=2087863
# [Reviews] 420/513 book_id=2155808
# [Reviews] 421/513 book_id=1940600
# [Reviews] 422/513 book_id=1683608
# [Reviews] 423/513 book_id=1666646
# [Reviews] 424/513 book_id=1658449
# [Reviews] 425/513 book_id=2167702
# [Reviews] 426/513 book_id=2167703
# [Reviews] 427/513 book_id=1943530
# [Reviews] 428/513 book_id=2161168
# [Reviews] 429/513 book_id=1940692
# [Reviews] 430/513 book_id=1968994
# [Reviews] 431/513 book_id=2018993
# [Reviews] 432/513 book_id=1821295
# [Reviews] 433/513 book_id=2161335
# [Reviews] 434/513 book_id=2187702
# [Reviews] 435/513 book_id=1864204
# [Reviews] 436/513 book_id=2324039
# [Reviews] 437/513 book_id=2282669
# [Reviews] 438/513 book_id=2165888
# [Reviews] 439/513 book_id=2136117
# [Reviews] 440/513 book_id=1685495
# [Reviews] 441/513 book_id=1831181
# [Reviews] 442/513 book_id=2167627
# [Reviews] 443/513 book_id=2065673
# [Reviews] 444/513 book_id=2169712
# [Reviews] 445/513 book_id=1944448
# [Reviews] 446/513 book_id=2329564
# [Reviews] 447/513 book_id=1829006
# [Reviews] 448/513 book_id=1940686
# [Reviews] 449/513 book_id=1775693
# [Reviews] 450/513 book_id=2169785
# [Reviews] 451/513 book_id=1793471
# [Reviews] 452/513 book_id=2214851
# [Reviews] 453/513 book_id=2169703
# [Reviews] 454/513 book_id=2169783
# [Reviews] 455/513 book_id=1758367
# [Reviews] 456/513 book_id=2156860
# [Reviews] 457/513 book_id=2074824
# [Reviews] 458/513 book_id=1924491
# [Reviews] 459/513 book_id=1845200
# [Reviews] 460/513 book_id=1939388
# [Reviews] 461/513 book_id=2134417
# [Reviews] 462/513 book_id=1800126
# [Reviews] 463/513 book_id=1959954
# [Reviews] 464/513 book_id=1800123
# [Reviews] 465/513 book_id=1892542
# [Reviews] 466/513 book_id=1725444
# [Reviews] 467/513 book_id=2383653
# [Reviews] 468/513 book_id=2137211
# [Reviews] 469/513 book_id=2164169
# [Reviews] 470/513 book_id=2193677
# [Reviews] 471/513 book_id=1959180
# [Reviews] 472/513 book_id=2172035
# [Reviews] 473/513 book_id=2145973
# [Reviews] 474/513 book_id=1909080
# [Reviews] 475/513 book_id=2045635
# [Reviews] 476/513 book_id=2329027
# [Reviews] 477/513 book_id=2333044
# [Reviews] 478/513 book_id=2077903
# [Reviews] 479/513 book_id=1985556
# [Reviews] 480/513 book_id=1844035
# [Reviews] 481/513 book_id=1986895
# [Reviews] 482/513 book_id=2172489
# [Reviews] 483/513 book_id=1667344
# [Reviews] 484/513 book_id=1906157
# [Reviews] 485/513 book_id=2078108
# [Reviews] 486/513 book_id=1718141
# [Reviews] 487/513 book_id=2078104
# [Reviews] 488/513 book_id=2173315
# [Reviews] 489/513 book_id=2173316
# [Reviews] 490/513 book_id=1697909
# [Reviews] 491/513 book_id=1791209
# [Reviews] 492/513 book_id=1931466
# [Reviews] 493/513 book_id=1819109
# [Reviews] 494/513 book_id=2333067
# [Reviews] 495/513 book_id=2081375
# [Reviews] 496/513 book_id=2333073
# [Reviews] 497/513 book_id=1801831
# [Reviews] 498/513 book_id=1916627
# [Reviews] 499/513 book_id=2108164
# [Reviews] 500/513 book_id=2112564
# [Reviews] 501/513 book_id=2112223
# [Reviews] 502/513 book_id=2112179
# [Reviews] 503/513 book_id=2112225
# [Reviews] 504/513 book_id=2112466
# [Reviews] 505/513 book_id=2112214
# [Reviews] 506/513 book_id=2112317
# [Reviews] 507/513 book_id=2112168
# [Reviews] 508/513 book_id=2112301
# [Reviews] 509/513 book_id=2112570
# [Reviews] 510/513 book_id=2112169
# [Reviews] 511/513 book_id=2112202
# [Reviews] 512/513 book_id=2112180
# [Reviews] 513/513 book_id=2112556
# Reviews fetched: (633, 3)
#
# After min-review filter:
# Books: (66, 5) | Reviews: (490, 3)
#
# === JOIN ===
# Final dataset: (490, 7)
#  book_id                review_created_at                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            review_raw                     title            book_created_at                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           description                      authors
#  1684749 2025-06-09T20:56:58.950471+00:00 "Broken are the roots of chaos."In this novella (which, let's be honest, is about the size of a regular novel from anyone else), we're two years prior to the events of Priory of the Orange Tree, and focused almost squarely on Marosa, queen of Yscalin. Carscaro is a city built on fire, with lava flowing in canals and Mount Fruma behind them. Inside this mountain is where Fýredel has been sleeping for 500 years. Unfortunately, this is the year when Fýredel stirs, putting all of Carscaro in danger. Later in the book, we also follow Aubrecht, the high prince of Mentedon and betrothed to Marosa, as he struggles to discover the fate of his fiancee in the wake of Fýredel's awakening. Finally, rounding out the cast of POVs, we have Melaugo, a culler of sleepers (beasts turned into half wyrms and then put to sleep), who, together with her lover, have to find their way out of a nation under siege.The author bills this as a companion book to Priory of the Orange Tree, and I agree with that. While this can be read on its own, I think if you want any sort of closure or continuance on events, you need to read Priory of the Orange Tree to get it. But I do think this highlights the fact that not only can the author write giant 1000+ page epics, she can also write shorter bites of her world's larger history for fans too.I loved Marosa's viewpoint best of the ones presented here. She carries herself well in the face of everything crumbling around her, and the ending (such as it is, presented here) had me feeling all sorts of things for her. If you've already read Priory of the Orange Tree you already have an idea of what's to come here, but it still manages to catch me by surprise. Aubrecht's viewpoint, too, really hit me in the feels, as he struggles to figure out what to do personally and publicly after Fýredel awakens. The third viewpoint, Melaugo, was interesting, but felt a bit removed from the other two. The author uses her as a window into how events impact the common folk of Yscalin, but it never actually intersects at all with either Marosa or Aubrecht at this point so it just felt a little tacked on.There is a romance here, because it is Samantha Shannon, but the romance is already established before the book starts, so there's no development or anything beyond some ex- drama that needs resolving.I did absolutely enjoy this book though, and look forward to more "short" stories in this Roots of Chaos series she's squeezing in amongst her main books.  Among the Burning Flowers 2025-01-09T14:41:53.515668 With the awakening of fire-breathing dragons, Among the Burning Flowers sees the first sparks of danger that threaten to consume the world in The Priory of the Orange Tree.\n\nTake your first steps into the epic.\n\nYscalin, land of sunshine and lavender, will soon be ablaze.\n\nIt has been centuries since the Draconic Army took wing, almost extinguishing humankind.\n\nMarosa Vetalda is a prisoner in her own home, controlled by her cold father, King Sigoso. Over the mountains, her betrothed, Aubrecht Lievelyn, rules Mentendon in all but name. Together, they intend to usher in a better world.\n\nA better world seems impossibly distant to Estina Melaugo, who hunts the Draconic beasts that have slept across the world for centuries.\n\nAnd now the great wyrm Fýredel is stirring, and Yscalin will be the first to fall . . .\n\nA story of human resilience in the face of dire circumstances, Among the Burning Flowers leads readers through the gripping and tragic events that pave the way for the opening of the million-copy bestseller The Priory of The Orange Tree.\n\nRichly illustrated with magical artwork by Rovina Cai (@rovinacai). Samantha Shannon, Rovina Cai
#  1684749 2025-10-12T13:48:07.892371+00:00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      This was disappointing, considering how great the other two Priory books are. Samantha Shannon might not be cut out for the shorter format. When books are this short I expect every page to pack a punch and for it to have a defined goal. This did neither of those things. Rather, it was like a full-length novel packed into a quarter of the pages, with a quarter of the impact. It’s still worth the read if you loved Priory because it adds some context to what’s going on at that time, but is definitely the weakest of the bunch. Among the Burning Flowers 2025-01-09T14:41:53.515668 With the awakening of fire-breathing dragons, Among the Burning Flowers sees the first sparks of danger that threaten to consume the world in The Priory of the Orange Tree.\n\nTake your first steps into the epic.\n\nYscalin, land of sunshine and lavender, will soon be ablaze.\n\nIt has been centuries since the Draconic Army took wing, almost extinguishing humankind.\n\nMarosa Vetalda is a prisoner in her own home, controlled by her cold father, King Sigoso. Over the mountains, her betrothed, Aubrecht Lievelyn, rules Mentendon in all but name. Together, they intend to usher in a better world.\n\nA better world seems impossibly distant to Estina Melaugo, who hunts the Draconic beasts that have slept across the world for centuries.\n\nAnd now the great wyrm Fýredel is stirring, and Yscalin will be the first to fall . . .\n\nA story of human resilience in the face of dire circumstances, Among the Burning Flowers leads readers through the gripping and tragic events that pave the way for the opening of the million-copy bestseller The Priory of The Orange Tree.\n\nRichly illustrated with magical artwork by Rovina Cai (@rovinacai). Samantha Shannon, Rovina Cai
#  1684749 2025-11-08T21:09:35.594427+00:00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        It was amazing getting to know those we met in Priory as side-characters and getting a glimpse into their lives before the main events.I fell deeply in love with Marosa as a character and hope we get to see her healing her country in the Priory sequel.I didn't expect to love and mourn Marosa and Aubrecht's engagement Among the Burning Flowers 2025-01-09T14:41:53.515668 With the awakening of fire-breathing dragons, Among the Burning Flowers sees the first sparks of danger that threaten to consume the world in The Priory of the Orange Tree.\n\nTake your first steps into the epic.\n\nYscalin, land of sunshine and lavender, will soon be ablaze.\n\nIt has been centuries since the Draconic Army took wing, almost extinguishing humankind.\n\nMarosa Vetalda is a prisoner in her own home, controlled by her cold father, King Sigoso. Over the mountains, her betrothed, Aubrecht Lievelyn, rules Mentendon in all but name. Together, they intend to usher in a better world.\n\nA better world seems impossibly distant to Estina Melaugo, who hunts the Draconic beasts that have slept across the world for centuries.\n\nAnd now the great wyrm Fýredel is stirring, and Yscalin will be the first to fall . . .\n\nA story of human resilience in the face of dire circumstances, Among the Burning Flowers leads readers through the gripping and tragic events that pave the way for the opening of the million-copy bestseller The Priory of The Orange Tree.\n\nRichly illustrated with magical artwork by Rovina Cai (@rovinacai). Samantha Shannon, Rovina Cai
#  1684749 2025-12-01T14:19:11.766224+00:00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         If you're a fan of "The Roots of Chaos" series, this book serves as an excellent transition between the two volumes. However, it is heavily reliant on knowing who the characters from the Priory are before diving in.Perhaps if I hadn't read the Priory first, then I would have enjoyed it more. I can see how satisfying it would be to go from this book into the next, following through to their conclusions.I look forward to more from this series. Among the Burning Flowers 2025-01-09T14:41:53.515668 With the awakening of fire-breathing dragons, Among the Burning Flowers sees the first sparks of danger that threaten to consume the world in The Priory of the Orange Tree.\n\nTake your first steps into the epic.\n\nYscalin, land of sunshine and lavender, will soon be ablaze.\n\nIt has been centuries since the Draconic Army took wing, almost extinguishing humankind.\n\nMarosa Vetalda is a prisoner in her own home, controlled by her cold father, King Sigoso. Over the mountains, her betrothed, Aubrecht Lievelyn, rules Mentendon in all but name. Together, they intend to usher in a better world.\n\nA better world seems impossibly distant to Estina Melaugo, who hunts the Draconic beasts that have slept across the world for centuries.\n\nAnd now the great wyrm Fýredel is stirring, and Yscalin will be the first to fall . . .\n\nA story of human resilience in the face of dire circumstances, Among the Burning Flowers leads readers through the gripping and tragic events that pave the way for the opening of the million-copy bestseller The Priory of The Orange Tree.\n\nRichly illustrated with magical artwork by Rovina Cai (@rovinacai). Samantha Shannon, Rovina Cai
#  1684749 2025-12-28T17:57:48.421256+00:00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                This is fine, but only as a companion piece to Priory. I don't believe it could be read as a starting point (despite what the author says), and it definitely couldn't be read as a stand alone; at least not an enjoyable one.While it was nice to spend more time with some of these characters, I am left wondering what the point of the book was. Among the Burning Flowers 2025-01-09T14:41:53.515668 With the awakening of fire-breathing dragons, Among the Burning Flowers sees the first sparks of danger that threaten to consume the world in The Priory of the Orange Tree.\n\nTake your first steps into the epic.\n\nYscalin, land of sunshine and lavender, will soon be ablaze.\n\nIt has been centuries since the Draconic Army took wing, almost extinguishing humankind.\n\nMarosa Vetalda is a prisoner in her own home, controlled by her cold father, King Sigoso. Over the mountains, her betrothed, Aubrecht Lievelyn, rules Mentendon in all but name. Together, they intend to usher in a better world.\n\nA better world seems impossibly distant to Estina Melaugo, who hunts the Draconic beasts that have slept across the world for centuries.\n\nAnd now the great wyrm Fýredel is stirring, and Yscalin will be the first to fall . . .\n\nA story of human resilience in the face of dire circumstances, Among the Burning Flowers leads readers through the gripping and tragic events that pave the way for the opening of the million-copy bestseller The Priory of The Orange Tree.\n\nRichly illustrated with magical artwork by Rovina Cai (@rovinacai). Samantha Shannon, Rovina Cai
#
# Saved: ..\data\Hardcover_2025.csv

# %% [markdown]
# # NYT Best Seller

# %% [markdown]
# ## NYT Books API - Fetch Best Sellers (Author & Title)

# %%
import requests
from datetime import datetime, timedelta
import time
import pandas as pd
import os
from pathlib import Path

API_KEY = os.getenv('NYT_API_KEY')

def fetch_bestsellers_for_date(date_str, api_key):
    """Fetch bestsellers using the date-specific endpoint"""
    url = f"https://api.nytimes.com/svc/books/v3/lists/{date_str}/combined-print-and-e-book-fiction.json"
    params = {'api-key': api_key}
    return requests.get(url, params=params)

def get_all_wednesdays(start_date, end_date):
    """Generate all Wednesdays between start and end dates"""
    wednesdays = []
    current = start_date
    
    # Move to first Wednesday (weekday 2)
    while current.weekday() != 2:
        current += timedelta(days=1)
    
    while current <= end_date:
        wednesdays.append(current)
        current += timedelta(days=7)
    
    return wednesdays

# Date range
start_date = datetime(2025, 1, 1)
end_date = datetime.now()

wednesdays = get_all_wednesdays(start_date, end_date)
print(f"Fetching {len(wednesdays)} weeks from {wednesdays[0].date()} to {wednesdays[-1].date()}\n")

all_books = []
successful_weeks = 0
failed_weeks = 0

for i, wednesday in enumerate(wednesdays, 1):
    date_str = wednesday.strftime('%Y-%m-%d')
    
    try:
        response = fetch_bestsellers_for_date(date_str, API_KEY)
        
        if response.status_code == 200:
            data = response.json()
            
            # Navigate to books
            if 'results' in data and 'books' in data['results']:
                books = data['results']['books']
                published_date = data['results'].get('published_date', date_str)
                
                for book in books:
                    all_books.append({
                        'published_date': published_date,
                        'title': book.get('title', 'Unknown'),
                        'author': book.get('author', 'Unknown'),
                        'rank': book.get('rank'),
                        'weeks_on_list': book.get('weeks_on_list', 0)
                    })
                
                successful_weeks += 1
                print(f"✓ [{i}/{len(wednesdays)}] {date_str} → {published_date}: {len(books)} books")
            else:
                failed_weeks += 1
                print(f"⚠ [{i}/{len(wednesdays)}] {date_str}: No books in response")
        
        elif response.status_code == 404:
            failed_weeks += 1
            print(f"⚠ [{i}/{len(wednesdays)}] {date_str}: Not published")
        
        elif response.status_code == 401:
            print(f"✗ [{i}/{len(wednesdays)}] {date_str}: API key error - STOPPING")
            break
        
        else:
            failed_weeks += 1
            print(f"✗ [{i}/{len(wednesdays)}] {date_str}: Error {response.status_code}")
        
        # Rate limit: 5 requests per minute
        time.sleep(12)
        
    except Exception as e:
        failed_weeks += 1
        print(f"✗ [{i}/{len(wednesdays)}] {date_str}: Exception - {e}")

# Save results
print(f"\n{'='*70}")
print(f"Summary: {successful_weeks} successful, {failed_weeks} failed")

if all_books:
    df = pd.DataFrame(all_books)
    
    # Sort by date and rank
    df = df.sort_values(['published_date', 'rank'])
    
    (Path('..') / 'data').mkdir(parents=True, exist_ok=True)
    nyt_path = Path('..') / 'data' / 'nyt_bestsellers_2025.csv'
    df.to_csv(str(nyt_path), index=False)
    
    print(f"✓ Total entries: {len(df)}")
    print(f"✓ Unique books: {df[['title', 'author']].drop_duplicates().shape[0]}")
    print(f"✓ Date range: {df['published_date'].min()} to {df['published_date'].max()}")
    print(f"✓ Saved to: {nyt_path}")
    print(f"{'='*70}")
    
    print("\nSample of data:")
    print(df[['published_date', 'rank', 'title', 'author']].head(10))
    
    print("\nUnique books:")
    unique = df[['title', 'author']].drop_duplicates()
    print(unique.head(10))
    unique_path = Path('..') / 'data' / 'nyt_unique_books_2025.csv'
    unique.to_csv(str(unique_path), index=False)
    print(f"Saved {len(unique)} unique books to {unique_path}")
    
else:
    print("No data collected - check API key and date range")
    print(f"{'='*70}")
# Out:
# Fetching 58 weeks from 2025-01-01 to 2026-02-04
#
# ✓ [1/58] 2025-01-01 → 2024-12-29: 15 books
# ✓ [2/58] 2025-01-08 → 2025-01-05: 15 books
# ✓ [3/58] 2025-01-15 → 2025-01-12: 15 books
# ✓ [4/58] 2025-01-22 → 2025-01-19: 15 books
# ✓ [5/58] 2025-01-29 → 2025-01-26: 15 books
# ✓ [6/58] 2025-02-05 → 2025-02-02: 15 books
# ✓ [7/58] 2025-02-12 → 2025-02-09: 15 books
# ✓ [8/58] 2025-02-19 → 2025-02-16: 15 books
# ✓ [9/58] 2025-02-26 → 2025-02-23: 15 books
# ✓ [10/58] 2025-03-05 → 2025-03-02: 15 books
# ✓ [11/58] 2025-03-12 → 2025-03-09: 15 books
# ✓ [12/58] 2025-03-19 → 2025-03-16: 15 books
# ✓ [13/58] 2025-03-26 → 2025-03-23: 15 books
# ✓ [14/58] 2025-04-02 → 2025-03-30: 15 books
# ✓ [15/58] 2025-04-09 → 2025-04-06: 15 books
# ✓ [16/58] 2025-04-16 → 2025-04-13: 15 books
# ✓ [17/58] 2025-04-23 → 2025-04-20: 15 books
# ✓ [18/58] 2025-04-30 → 2025-04-27: 15 books
# ✓ [19/58] 2025-05-07 → 2025-05-04: 15 books
# ✓ [20/58] 2025-05-14 → 2025-05-11: 15 books
# ✓ [21/58] 2025-05-21 → 2025-05-18: 15 books
# ✓ [22/58] 2025-05-28 → 2025-05-25: 15 books
# ✓ [23/58] 2025-06-04 → 2025-06-01: 15 books
# ✓ [24/58] 2025-06-11 → 2025-06-08: 15 books
# ✓ [25/58] 2025-06-18 → 2025-06-15: 15 books
# ✓ [26/58] 2025-06-25 → 2025-06-22: 15 books
# ✓ [27/58] 2025-07-02 → 2025-06-29: 15 books
# ✓ [28/58] 2025-07-09 → 2025-07-06: 15 books
# ✓ [29/58] 2025-07-16 → 2025-07-13: 15 books
# ✓ [30/58] 2025-07-23 → 2025-07-20: 15 books
# ✓ [31/58] 2025-07-30 → 2025-07-27: 15 books
# ✓ [32/58] 2025-08-06 → 2025-08-03: 15 books
# ✓ [33/58] 2025-08-13 → 2025-08-10: 15 books
# ✓ [34/58] 2025-08-20 → 2025-08-17: 15 books
# ✓ [35/58] 2025-08-27 → 2025-08-24: 15 books
# ✓ [36/58] 2025-09-03 → 2025-08-31: 15 books
# ✓ [37/58] 2025-09-10 → 2025-09-07: 15 books
# ✓ [38/58] 2025-09-17 → 2025-09-14: 15 books
# ✓ [39/58] 2025-09-24 → 2025-09-21: 15 books
# ✓ [40/58] 2025-10-01 → 2025-09-28: 15 books
# ✓ [41/58] 2025-10-08 → 2025-10-05: 15 books
# ✓ [42/58] 2025-10-15 → 2025-10-12: 15 books
# ✓ [43/58] 2025-10-22 → 2025-10-19: 15 books
# ✓ [44/58] 2025-10-29 → 2025-10-26: 15 books
# ✓ [45/58] 2025-11-05 → 2025-11-02: 15 books
# ✓ [46/58] 2025-11-12 → 2025-11-09: 15 books
# ✓ [47/58] 2025-11-19 → 2025-11-16: 15 books
# ✓ [48/58] 2025-11-26 → 2025-11-23: 15 books
# ✓ [49/58] 2025-12-03 → 2025-11-30: 15 books
# ✓ [50/58] 2025-12-10 → 2025-12-07: 15 books
# ✓ [51/58] 2025-12-17 → 2025-12-14: 15 books
# ✓ [52/58] 2025-12-24 → 2025-12-21: 15 books
# ✓ [53/58] 2025-12-31 → 2025-12-28: 15 books
# ✓ [54/58] 2026-01-07 → 2026-01-04: 15 books
# ✓ [55/58] 2026-01-14 → 2026-01-11: 15 books
# ✓ [56/58] 2026-01-21 → 2026-01-18: 15 books
# ✓ [57/58] 2026-01-28 → 2026-01-25: 15 books
# ✓ [58/58] 2026-02-04 → 2026-02-01: 15 books
#
# ======================================================================
# Summary: 58 successful, 0 failed
# ✓ Total entries: 870
# ✓ Unique books: 259
# ✓ Date range: 2024-12-29 to 2026-02-01
# ✓ Saved to: ..\data\nyt_bestsellers_2025.csv
# ======================================================================
#
# Sample of data:
#   published_date  rank                        title             author
# 0     2024-12-29     1                        JAMES   Percival Everett
# 1     2024-12-29     2               WIND AND TRUTH  Brandon Sanderson
# 2     2024-12-29     3                       WICKED    Gregory Maguire
# 3     2024-12-29     4                    THE WOMEN     Kristin Hannah
# 4     2024-12-29     5                  FOURTH WING     Rebecca Yarros
# 5     2024-12-29     6           THE HOUSE OF CROSS    James Patterson
# 6     2024-12-29     7         THE GOD OF THE WOODS          Liz Moore
# 7     2024-12-29     8           THE WEDDING PEOPLE      Alison Espach
# 8     2024-12-29     9             THE FROZEN RIVER       Ariel Lawhon
# 9     2024-12-29    10  A COURT OF THORNS AND ROSES      Sarah J. Maas
#
# Unique books:
#                          title             author
# 0                        JAMES   Percival Everett
# 1               WIND AND TRUTH  Brandon Sanderson
# 2                       WICKED    Gregory Maguire
# 3                    THE WOMEN     Kristin Hannah
# 4                  FOURTH WING     Rebecca Yarros
# 5           THE HOUSE OF CROSS    James Patterson
# 6         THE GOD OF THE WOODS          Liz Moore
# 7           THE WEDDING PEOPLE      Alison Espach
# 8             THE FROZEN RIVER       Ariel Lawhon
# 9  A COURT OF THORNS AND ROSES      Sarah J. Maas
# Saved 259 unique books to ..\data\nyt_unique_books_2025.csv
